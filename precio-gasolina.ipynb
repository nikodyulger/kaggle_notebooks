# %% [markdown]
# <a href="https://www.kaggle.com/code/nikoladyulgerov/r-pido-y-furioso-el-precio-de-la-gasolina?scriptVersionId=228310321" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd 
import plotly.express as px
import plotly.io as pio

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Descripción general de los datos

# %%
df_gasolineras = pd.read_csv("/kaggle/input/precios-de-gasolineras-de-albacete/gasolineras_ab.csv")
df_precios = pd.read_csv("/kaggle/input/precios-de-gasolineras-de-albacete/precios_gasolineras.csv", parse_dates=['fecha'], date_format='%d/%m/%y' )

# %%
df_gasolineras.head()
# Out:
#    id_estacion                                          direccion  cod_postal  \
# 0        10765                            AVENIDA 1º DE MAYO, S/N        2001
# 1        12054  CALLE PRINCIPE DE ASTURIAS (POLÍGONO DE ROMICA...        2001
# 2        13933                     CALLE FEDERICO GARCIA LORCA, 1        2001
# 3         4369                         AVENIDA MENÉNDEZ PIDAL, 58        2005
# 4         5195                            CL PASEO DE LA CUBA, 15        2005
#
#      latitud  longitud     rotulo                           horario municipio
# 0  38.985667 -1.868500  CARREFOUR  L-S: 08:00-22:00; D: 09:00-21:00  Albacete
# 1  39.054694 -1.832000  BP ROMICA                  L-D: 06:00-22:00  Albacete
# 2  39.000861 -1.849833    PLENOIL                          L-D: 24H  Albacete
# 3  39.003333 -1.864917      TAMOS                          L-D: 24H  Albacete
# 4  38.999722 -1.854556     REPSOL                  L-D: 06:00-22:00  Albacete

# %%
df_precios.head()
# Out:
#    id_estacion       fecha  precio_gasoleo_a  precio_gasoleo_premium  \
# 0        10765  01/01/2022             1.399                   1.399
# 1        12054  01/01/2022             1.389                   1.389
# 2        13933  01/01/2022             1.249                     NaN
# 3         4369  01/01/2022             1.359                   1.359
# 4         5195  01/01/2022             1.409                   1.409
#
#    precio_gasolina_95  precio_gasolina_98
# 0               1.519               1.639
# 1               1.479               1.621
# 2               1.389                 NaN
# 3               1.479               1.599
# 4               1.509               1.619

# %%
df_gasolineras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_estacion  42 non-null     int64
#  1   direccion    42 non-null     object
#  2   cod_postal   42 non-null     int64
#  3   latitud      42 non-null     float64
#  4   longitud     42 non-null     float64
#  5   rotulo       42 non-null     object
#  6   horario      42 non-null     object
#  7   municipio    42 non-null     object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 2.8+ KB

# %%
df_precios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47089 entries, 0 to 47088
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id_estacion             47089 non-null  int64
#  1   fecha                   47089 non-null  object
#  2   precio_gasoleo_a        46004 non-null  float64
#  3   precio_gasoleo_premium  32054 non-null  float64
#  4   precio_gasolina_95      43818 non-null  float64
#  5   precio_gasolina_98      27543 non-null  float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
df_precios.describe()
# Out:
#         id_estacion  precio_gasoleo_a  precio_gasoleo_premium  \
# count  47089.000000      46004.000000            32054.000000
# mean    8874.081781          1.615661                1.637473
# std     4164.742397          0.219800                0.200046
# min     4369.000000          1.149000                1.149000
# 25%     5129.000000          1.455000                1.489000
# 50%     5318.000000          1.569000                1.589000
# 75%    13369.000000          1.759000                1.759000
# max    16011.000000          2.259000                2.179000
#
#        precio_gasolina_95  precio_gasolina_98
# count        43818.000000        27543.000000
# mean             1.668314            1.824796
# std              0.169220            0.165441
# min              1.259000            1.379000
# 25%              1.559000            1.719000
# 50%              1.634000            1.789000
# 75%              1.739000            1.891000
# max              2.299000            2.379000

# %% [markdown]
# ## Análisis Exploratorio

# %%
df_gasolineras['id_estacion'].nunique() # Total de gasolineras en el municipio
# Out:
# 42

# %%
df_gasolineras['cod_postal'].value_counts()
# Out:
# cod_postal
# 2007    15
# 2006    11
# 2005     5
# 2080     4
# 2001     3
# 2002     1
# 2099     1
# 2004     1
# 2328     1
# Name: count, dtype: int64

# %% [markdown]
# Donde más gasolineras se ubican es en el **polígono Industrial de Campollano** (código postal `02007`) seguido de la área Oeste de la ciudad (`02006`)

# %%
import folium

coord_ab = [39.00, -1.86] # coordenadas orientativas

# Crea el mapa centrado en la ciudad
mapa_ab = folium.Map(location=coord_ab, zoom_start=12)

# Añade marcadores para cada gasolinera
for index, row in df_gasolineras.iterrows():
    folium.Marker(
        location=[row['latitud'], row['longitud']],
        popup=row['direccion'],
        tooltip=row['rotulo']
    ).add_to(mapa_ab)

mapa_ab
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c19c583a56046e960798ba322dd7b72e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c19c583a56046e960798ba322dd7b72e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c19c583a56046e960798ba322dd7b72e = L.map(
#                 &quot;map_c19c583a56046e960798ba322dd7b72e&quot;,
#                 {
#                     center: [39.0, -1.86],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6687277b61bac06ec9e2cedebdc0ee22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6687277b61bac06ec9e2cedebdc0ee22.addTo(map_c19c583a56046e960798ba322dd7b72e);
#
#
#             var marker_677e699a99c5f6f1dc2cd3250909ff39 = L.marker(
#                 [38.985667, -1.8685],
#                 {
# }
#             ).addTo(map_c19c583a56046e960798ba322dd7b72e);
#
#
#         var popup_edd3894620bc3cfe9eba10486cd1bc46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e4bf7de7202272d7f91adfebed27a2d = $(`&lt;div id=&quot;html_2e4bf7de7202272d7f91adfebed27a2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AVENIDA 1º DE MAYO, S/N&lt;/div&gt;`)[0];
#                 popup_edd3894620bc3cfe9eba10486cd1bc46.setContent(html_2e4bf7de7202272d7f91adfebed27a2d);
#
#
#
#         marker_677e699a99c5f6f1dc2cd3250909ff39.bindPopup(popup_edd3894620bc3cfe9eba10486cd1bc46)
#         ;
#
#
#
#
#             marker_677e699a99c5f6f1dc2cd3250909ff39.bindTooltip(
#                 `&lt;div&gt;
#                      CARREFOUR
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_195eb48df695c44197420a1fdc369327 = L.marker(
#                 [39.054694, -1.832],
#                 {
# }
#             ).addTo(map_c19c583a56046e960798ba322dd7b72e);
#
#
#         var popup_4d24b82f3f8ac260e2534c8028db9fe6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1b64edc753ec168b20fee5ef7491a4d = $(`&lt;div id=&quot;html_b1b64edc753ec168b20fee5ef7491a4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CALLE PRINCIPE DE ASTURIAS (POLÍGONO DE ROMICA), 5&lt;/div&gt;`)[0];
#                 popup_4d24b82f3f8ac260e2534c8028db9fe6.setContent(html_b1b64edc753ec168b20fee5ef7491a4d);
#
#
#
#         marker_195eb48df695c44197420a1fdc369327.bindPopup(popup_4d24b82f3f8ac260e2534c8028db9fe6)
#         ;
#
#
#
#
#             marker_195eb48df695c44197420a1fdc369327.bindTooltip(
#                 `&lt;div&gt;
#                      BP ROMICA
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0e7735b3dc997c0655b9d1b55e23c7fc = L.marker(
#                 [39.000861, -1.849833],
#                 {
# }
#             ).addTo(map_c19c583a56046e960798ba322dd7b72e);
#
#
#         var popup_f8090fb72b536d7c5059c41cf68b5087 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da0748b99d921f24dbec75d9d26f0481 = $(`&lt;div id=&quot;html_da0748b99d921f24dbec75d9d26f0481&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CALLE FEDERICO GARCIA LORCA, 1&lt;/div&gt;`)[0];
#                 popup_f8090fb72b536d7c5059c41cf68b5087.setContent(html_da0748b99d921f24dbec75d9d26f0481);
#
#
#
#         marker_0e7735b3dc997c0655b9d1b55e23c7fc.bindPopup(popup_f8090fb72b536d7c5059c41cf68b5087)
#         ;
#
#
#
#
#             marker_0e7735b3dc997c0655b9d1b55e23c7fc.bindTooltip(
#                 `&lt;div&gt;
#                      PLENOIL
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_fba1535c724e251873add040f4c0dfb5 = L.marker(
#                 [39.003333, -1.864917],
#                 {
# }
#             ).addTo(map_c19c583a56046e960798ba322dd7b72e);
#
#
#         var popup_65ffe168d75c9a7db49323c989444131 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a74998c203b3b58d36efed10768e5d1e = $(`&lt;div id=&quot;html_a74998c203b3b58d36efed10768e5d1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AVENIDA MENÉNDEZ PIDAL, 58&lt;/div&gt;`)[0];
#                 popup_65ffe168d75c9a7db49323c989444131.setContent(html_a74998c203b3b58d36efed10768e5d1e);
#
#
#
#         marker_fba1535c724e251873add040f4c0dfb5.bindPopup(popup_65ffe168d75c9a7db49323c989444131)
#         ;
#
#
#
#
#             marker_fba1535c724e251873add040f4c0dfb5.bindTooltip(
#                 `&lt;div&gt;
#                      TAMOS
#                  &lt;/div&gt;`,

# %%
df_gasolineras['rotulo'].value_counts().head()
# Out:
# rotulo
# REPSOL       9
# CEPSA        7
# INPEALSA     4
# PLENOIL      2
# CARREFOUR    1
# Name: count, dtype: int64

# %% [markdown]
# Las gasolineras que predominan son las de **Repsol** y **Cepsa**

# %%
df_gasolineras['horario'].value_counts().head()
# Out:
# horario
# L-D: 24H                              15
# L-D: 06:00-22:00                       6
# L-D: 07:00-23:00                       4
# L-V: 07:00-21:00; S-D: 09:00-14:00     2
# L-D: 06:30-22:30                       2
# Name: count, dtype: int64

# %% [markdown]
# Hay un número significativo de gasolineras que abren 24 horas del día.
#
# **NOTA** Para un mejor análisis, estaría bien extraer el tiempo total de apertura y no "fiarnos" de los strings

# %%
# Para un mejor manejo de las fechas
df_precios['fecha'] = pd.to_datetime(df_precios['fecha'],format='%d/%m/%Y')

fecha_minima = df_precios['fecha'].min()
fecha_maxima = df_precios['fecha'].max()

print(f"Fecha INICIO {fecha_minima} y Fecha FIN {fecha_maxima}")
# Out:
# Fecha INICIO 2022-01-01 00:00:00 y Fecha FIN 2024-12-31 00:00:00

# %%
df_precios['fecha'].nunique() # debería ser igual a 365  * 3 años (2022, 2023 y 2024) ~ 1095
# Out:
# 1093

# %%
df_precios.isna().sum() / df_precios.shape[0] * 100
# Out:
# id_estacion                0.000000
# fecha                      0.000000
# precio_gasoleo_a           2.304147
# precio_gasoleo_premium    31.928901
# precio_gasolina_95         6.946421
# precio_gasolina_98        41.508633
# dtype: float64

# %% [markdown]
# Hay un gran número de valores perdidos para ciertos precios, veamos si siguen algun patrón.
#
# Una primera razón puede ser que no todas las gasolineras oferten los mismo productos, así que empecemos por ahí

# %%
(
    df_precios
    .groupby(by=['id_estacion'])
    .agg(
        {
            'precio_gasoleo_a': 'count',
            'precio_gasoleo_premium': 'count',
            'precio_gasolina_95': 'count',
            'precio_gasolina_98': 'count'
        })
    .sort_values(by="precio_gasoleo_a", ascending=False)
    .head()
)
# Out:
#              precio_gasoleo_a  precio_gasoleo_premium  precio_gasolina_95  \
# id_estacion
# 4369                     1093                    1093                1093
# 5245                     1093                    1093                1093
# 14377                    1093                       0                   0
# 14287                    1093                    1093                1093
# 13933                    1093                       0                1093
#
#              precio_gasolina_98
# id_estacion
# 4369                       1093
# 5245                       1093
# 14377                         0
# 14287                      1093
# 13933                         0

# %%
(
    df_precios
    .groupby(by=['id_estacion'])
    .agg(
        {
            'precio_gasoleo_a': 'count',
            'precio_gasoleo_premium': 'count',
            'precio_gasolina_95': 'count',
            'precio_gasolina_98': 'count'
        })
    .sort_values(by="precio_gasoleo_a", ascending=False)
    .tail()
)
# Out:
#              precio_gasoleo_a  precio_gasoleo_premium  precio_gasolina_95  \
# id_estacion
# 5318                      906                       0                 906
# 4394                      895                     895                 895
# 13620                     664                     664                 664
# 16011                     308                       0                 308
# 14612                       0                       0                   0
#
#              precio_gasolina_98
# id_estacion
# 5318                          0
# 4394                          0
# 13620                       664
# 16011                         0
# 14612                         0

# %% [markdown]
# Al agrupar vemos el patrón que siguen los valores nulos:
# - Si no hay ningun registro, significa que se producto no se vende en dicha gasolinera
# - Si hay menos de `1093` registros (total de días en tres años), significa que ese producto se incorporó con el tiempo o bien que la gasolinera es nueva
#
#
# **NOTA** Curioso caso de la gasolinera `14612` que no tiene registro de ningún tipo, quizás solo vende gas u otros combustibles

# %%
df_precios.duplicated().sum() / df_precios.shape[0] * 100
# Out:
# 0.0

# %% [markdown]
# No hay duplicados, por tanto tenemos que ver como manejar los valores nulos

# %% [markdown]
# Aquí tenemos que tener en cuenta que hay varias `time-series`: una por cada combinación de gasolinera y producto. Es decir un total de 42 gasolineras X 4 productos = 168 líneas temporales a priori independientes.

# %% [markdown]
# Para ver la evolución de precios, tomemos una gasolinera como ejemplo para simplificar los gráficos

# %%
id_gasolinera = 4369 # se puede hacer al azar, la tomamos de la anterior consulta
nombre_gasolinera = df_gasolineras[df_gasolineras['id_estacion'] == id_gasolinera]['rotulo'].values[0]
df = df_precios[df_precios['id_estacion'] == id_gasolinera]

fig = px.line(
    df,
    x='fecha',
    y=['precio_gasoleo_a', 'precio_gasoleo_premium', 'precio_gasolina_95', 'precio_gasolina_98'], 
    title=f'Evolución de Precios Gasolinera {nombre_gasolinera}',
    labels={'value': 'Precio (€)', 'fecha': 'Fecha'}
)
fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_20.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# Notas a tener en cuenta:
# - Llama mucho la atención que el precio del gasóleo A y el Premium se solapa completamente
# - Hubo un pico en el 2022 debido al inicio de la guerra en Ucrania
# - Las tendencias de los distintos productos es bastante similar a lo largo del tiempo

# %%
 # Gasolineras más baratas
(
    df_precios
    # .assign(year=df_precios['fecha'].dt.year)
    .groupby(['id_estacion'])
    .agg(
        precio_medio_gasoleo_a=('precio_gasoleo_a', 'mean'),
        std_precio_gasoleo_a=('precio_gasoleo_a', 'std'),
        precio_medio_gasolina_95=('precio_gasolina_95', 'mean'),
        std_precio_gasolina_95=('precio_gasolina_95', 'std')
    )
    .reset_index()
    .merge(df_gasolineras[['id_estacion','rotulo', 'direccion']], on='id_estacion', how='left') 
    .sort_values(by=['precio_medio_gasoleo_a','precio_medio_gasolina_95'], ascending=True) # mas BARATAS!!!
    .head()
)
# Out:
#     id_estacion  precio_medio_gasoleo_a  std_precio_gasoleo_a  \
# 44        16011                1.301893              0.063434
# 32        13369                1.484640              0.207859
# 36        13933                1.497918              0.211721
# 6          4428                1.499046              0.217244
# 42        15000                1.507103              0.218641
#
#     precio_medio_gasolina_95  std_precio_gasolina_95         rotulo  \
# 44                  1.423640                0.069622        PLENOIL
# 32                  1.532735                0.155014          GMOIL
# 36                  1.542608                0.153613        PLENOIL
# 6                   1.546328                0.161984  FAMILY ENERGY
# 42                  1.584357                0.160104            A&A
#
#                                     direccion
# 44              CALLE CONSTANTINO ROMERO, S/N
# 32                       AVENIDA PRIMERA, S/N
# 36             CALLE FEDERICO GARCIA LORCA, 1
# 6   CALLE ALCALDE CONANGLA (C.C. EROSKI), S/N
# 42          AVENIDA ESCRITOR RODRIGO RUBIO, 3

# %%
 # Gasolineras más caras
(
    df_precios
    # .assign(year=df_precios['fecha'].dt.year)
    .groupby(['id_estacion'])
    .agg(
        precio_medio_gasoleo_a=('precio_gasoleo_a', 'mean'),
        std_precio_gasoleo_a=('precio_gasoleo_a', 'std'),
        precio_medio_gasolina_95=('precio_gasolina_95', 'mean'),
        std_precio_gasolina_95=('precio_gasolina_95', 'std')
    )
    .reset_index()
    .merge(df_gasolineras[['id_estacion','rotulo', 'direccion']], on='id_estacion', how='left') 
    .sort_values(by=['precio_medio_gasoleo_a','precio_medio_gasolina_95'] , ascending=False) # mas CARAS!!!
    .head()
)
# Out:
#     id_estacion  precio_medio_gasoleo_a  std_precio_gasoleo_a  \
# 2          4413                1.913080              0.417415
# 33        13620                1.733367              0.204405
# 26        11048                1.686984              0.180787
# 7          4790                1.686823              0.184423
# 37        14123                1.674496              0.177693
#
#     precio_medio_gasolina_95  std_precio_gasolina_95                rotulo  \
# 2                   1.988298                0.367743                 ABOIL
# 33                  1.744949                0.146962                 CEPSA
# 26                  1.719813                0.126689                 CEPSA
# 7                   1.721681                0.138784  INLOCOR S.L. "CEPSA"
# 37                  1.710880                0.134343                 CEPSA
#
#                               direccion
# 2   POLIGONO CAMPOLLANO AVENIDA -0-, 69
# 33              POLIGONO CAMPOLLANO, 55
# 26              CARRETERA N-322 KM. 349
# 7             CARRETERA C-M 332 KM. 2,6
# 37                  PASEO CUBA (LA), 36
